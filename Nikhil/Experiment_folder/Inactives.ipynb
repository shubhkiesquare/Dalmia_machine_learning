# %%
#cd '/Users/nikhilsingh/Downloads/Dalmia_machine_learning/Nikhil'

# %%
import numpy as np 
import pandas as pd

# %%
result = pd.read_csv('Predicted_Churn.csv')
dealer_status = pd.read_excel('dealer_status.xlsx')

# %%
result.index = result['dealerId']
result.drop('dealerId', axis = 1 , inplace = True)
dealer_status.index = dealer_status['Unnamed: 0']
dealer_status.drop('Unnamed: 0', axis = 1 , inplace = True)

# %%
result_jul = result[result['creationTime']=='01-07-2023']

# %%
status_jul = dealer_status[dealer_status.index.isin(result_jul.index)]

# %%
status_jul['month_new_dealer'] = status_jul['month_new_dealer']-4

# %%
status_jul.drop(['2023-09', '2023-10'], axis = 1 , inplace = True)

# %%
status_jul
# Out:
#            2021-04    2021-05 2021-06    2021-07 2021-08    2021-09  \
# Unnamed: 0
# 7000059     Active     Active  Active     Active  Active     Active
# 7000218     Active     Active  Active  Active_1N  Active     Active
# 7000318     Active  Active_1N  Active  Active_1N  Active  Active_1N
# 7000460     Active     Active  Active     Active  Active     Active
# 7000654     Active     Active  Active     Active  Active     Active
# ...            ...        ...     ...        ...     ...        ...
# 7040640          -          -       -          -       -          -
# 7040682          -          -       -          -       -          -
# 7040710          -          -       -          -       -          -
# 7040736          -          -       -          -       -          -
# 7040757          -          -       -          -       -          -
#
#               2021-10    2021-11    2021-12 2022-01  ...    2022-12   2023-01  \
# Unnamed: 0                                           ...
# ...

# %%
# status_jul = status_jul[['2022-07', '2022-08', '2022-09',
#        '2022-10', '2022-11', '2022-12', '2023-01', '2023-02', '2023-03',
#        '2023-04', '2023-05', '2023-06','month_new_dealer']]

# %%
status_jul
# Out:
#            2021-04    2021-05 2021-06    2021-07 2021-08    2021-09  \
# Unnamed: 0
# 7000059     Active     Active  Active     Active  Active     Active
# 7000218     Active     Active  Active  Active_1N  Active     Active
# 7000318     Active  Active_1N  Active  Active_1N  Active  Active_1N
# 7000460     Active     Active  Active     Active  Active     Active
# 7000654     Active     Active  Active     Active  Active     Active
# ...            ...        ...     ...        ...     ...        ...
# 7040640          -          -       -          -       -          -
# 7040682          -          -       -          -       -          -
# 7040710          -          -       -          -       -          -
# 7040736          -          -       -          -       -          -
# 7040757          -          -       -          -       -          -
#
#               2021-10    2021-11    2021-12 2022-01  ...    2022-12   2023-01  \
# Unnamed: 0                                           ...
# ...

# %%
status_jul['actual'] = 0
condition = ((status_jul['2023-07']=='Active_3N')|(status_jul['2023-08']=='Active_3N'))
status_jul.loc[condition, 'actual'] = 1
status_jul['actual'].value_counts()
# Out:
# 1    522
# 0    330
# Name: actual, dtype: int64

# %%
result_jun = result[result['creationTime']=='01-06-2023']
status_jun = dealer_status[dealer_status.index.isin(result_jun.index)]
status_jun['month_new_dealer'] = status_jun['month_new_dealer']-5
status_jun.drop(['2023-08', '2023-09','2023-10'], axis = 1 , inplace = True)

# %%
status_jun['actual'] = 0
condition = ((status_jun['2023-06']=='Active_3N')|(status_jun['2023-07']=='Active_3N'))
status_jun.loc[condition, 'actual'] = 1
status_jun['actual'].value_counts()
# Out:
# 1    573
# 0    267
# Name: actual, dtype: int64

# %%
# status_jun = status_jun[['2022-06','2022-07', '2022-08', '2022-09',
#        '2022-10', '2022-11', '2022-12', '2023-01', '2023-02', '2023-03',
#        '2023-04', '2023-05','month_new_dealer']]
status_jun
# Out:
#            2021-04    2021-05    2021-06    2021-07 2021-08    2021-09  \
# Unnamed: 0
# 7000027     Active     Active     Active     Active  Active     Active
# 7000059     Active     Active     Active     Active  Active     Active
# 7000104          -     Active     Active     Active  Active     Active
# 7000318     Active  Active_1N     Active  Active_1N  Active  Active_1N
# 7000525          -     Active  Active_1N     Active  Active     Active
# ...            ...        ...        ...        ...     ...        ...
# 7040017          -          -          -          -       -          -
# 7040026          -          -          -          -       -          -
# 7040058          -          -          -          -       -          -
# 7040110          -          -          -          -       -          -
# 7040113          -          -          -          -       -          -
#
#            2021-10    2021-11    2021-12 2022-01  ...    2022-11    2022-12  \
# ...

# %%
result_may = result[result['creationTime']=='01-05-2023']
status_may = dealer_status[dealer_status.index.isin(result_may.index)]
status_may['month_new_dealer'] = status_may['month_new_dealer']-6
status_may.drop(['2023-07', '2023-08', '2023-09','2023-10'], axis = 1 , inplace = True)

# %%
status_may['actual'] = 0
condition = ((status_may['2023-05']=='Active_3N')|(status_may['2023-06']=='Active_3N'))
status_may.loc[condition, 'actual'] = 1
status_may['actual'].value_counts()
# Out:
# 1    510
# 0    328
# Name: actual, dtype: int64

# %%
# status_may = status_may[['2022-05','2022-06','2022-07', '2022-08', '2022-09',
#        '2022-10', '2022-11', '2022-12', '2023-01', '2023-02', '2023-03',
#        '2023-04','month_new_dealer']]
status_may
# Out:
#            2021-04    2021-05 2021-06    2021-07 2021-08    2021-09  \
# Unnamed: 0
# 7000022          -          -       -          -       -          -
# 7000085          -          -       -          -       -     Active
# 7000205          -          -       -          -       -          -
# 7000603     Active  Active_1N  Active     Active  Active     Active
# 7000694          -          -  Active  Active_1N  Active  Active_1N
# ...            ...        ...     ...        ...     ...        ...
# 7039604          -          -       -          -       -          -
# 7039616          -          -       -          -       -          -
# 7039714          -          -       -          -       -          -
# 7039715          -          -       -          -       -          -
# 7039790          -          -       -          -       -          -
#
#               2021-10    2021-11    2021-12    2022-01  ... 2022-10  \
# Unnamed: 0                                              ...
# ...

# %%
status_jul_1 = status_jul[['actual','month_new_dealer']]
status_jun_1 = status_jun[['actual','month_new_dealer']]
status_may_1 = status_may[['actual','month_new_dealer']]

# %%
status_jul_1 ['actual'] =status_jul_1['actual'].replace({0:'Not_churn', 1:'Churn'})
status_jun_1 ['actual'] =status_jun_1['actual'].replace({0:'Not_churn', 1:'Churn'})
status_may_1 ['actual'] =status_may_1['actual'].replace({0:'Not_churn', 1:'Churn'})

# %%
status_jul_1 = status_jul_1.rename(columns={'month_new_dealer': 'dealer_history'})
status_jun_1 = status_jun_1.rename(columns={'month_new_dealer': 'dealer_history'})
status_may_1 = status_may_1.rename(columns={'month_new_dealer': 'dealer_history'})

# %%
with pd.ExcelWriter('churn_status_1.xlsx') as excel_file:
    status_jul_1.to_excel(excel_file, sheet_name='1st_jul', index=True)
    status_jun_1.to_excel(excel_file, sheet_name='1st_jun', index=True)
    status_may_1.to_excel(excel_file, sheet_name='1st_may', index=True)

# %%
result_apr = result[result['creationTime']=='01-04-2023']
status_apr = dealer_status[dealer_status.index.isin(result_apr.index)]
status_apr['month_new_dealer'] = status_apr['month_new_dealer']-7
#status_apr.drop(['2023-04','2023-05','2023-06','2023-07', '2023-08', '2023-09',
       '2023-10'], axis = 1 , inplace = True)
# Out:
# /var/folders/m3/m633mc4s5tsggxm0f81370l80000gn/T/ipykernel_36210/1393297963.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   status_apr['month_new_dealer'] = status_apr['month_new_dealer']-7
# /var/folders/m3/m633mc4s5tsggxm0f81370l80000gn/T/ipykernel_36210/1393297963.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   status_apr.drop(['2023-04','2023-05','2023-06','2023-07', '2023-08', '2023-09',

# %%
# def cap_value(value):
#     return min(value, 12)
# status_jul['month_new_dealer'] = status_jul['month_new_dealer'].apply(cap_value)
# status_jun['month_new_dealer'] = status_jun['month_new_dealer'].apply(cap_value)
# status_may['month_new_dealer'] = status_may['month_new_dealer'].apply(cap_value)
# status_apr['month_new_dealer'] = status_apr['month_new_dealer'].apply(cap_value)

# %%
status_jul = status_jul.rename(columns={'month_new_dealer': 'dealer_history'})
status_jun = status_jun.rename(columns={'month_new_dealer': 'dealer_history'})
status_may = status_may.rename(columns={'month_new_dealer': 'dealer_history'})
status_apr = status_apr.rename(columns={'month_new_dealer': 'dealer_history'})

# %%
status_apr
# Out:
#            2021-04    2021-05 2021-06 2021-07 2021-08    2021-09    2021-10  \
# Unnamed: 0
# 7000085          -          -       -       -       -     Active  Active_1N
# 7000158     Active     Active  Active  Active  Active  Active_1N     Active
# 7000189     Active     Active  Active  Active  Active     Active     Active
# 7000205          -          -       -       -       -          -          -
# 7000395     Active  Active_1N  Active  Active  Active  Active_1N  Active_2N
# ...            ...        ...     ...     ...     ...        ...        ...
# 7039256          -          -       -       -       -          -          -
# 7039271          -          -       -       -       -          -          -
# 7039289          -          -       -       -       -          -          -
# 7039291          -          -       -       -       -          -          -
# 7039303          -          -       -       -       -          -          -
#
# ...

# %%
with pd.ExcelWriter('churn_status.xlsx') as excel_file:
    status_jul.to_excel(excel_file, sheet_name='1st_jul', index=False)
    status_jun.to_excel(excel_file, sheet_name='1st_jun', index=False)
    status_may.to_excel(excel_file, sheet_name='1st_may', index=False)
    status_apr.to_excel(excel_file, sheet_name='1st_apr', index=False)

# %%
dealer_status[(dealer_status['2023-07']=='Active_3N')|(dealer_status['2023-08']=='Active_3N')&(dealer_status['month_new_dealer']>=12)]
# Out:
#            2021-04    2021-05 2021-06    2021-07 2021-08    2021-09  \
# Unnamed: 0
# 7000059     Active     Active  Active     Active  Active     Active
# 7000218     Active     Active  Active  Active_1N  Active     Active
# 7000318     Active  Active_1N  Active  Active_1N  Active  Active_1N
# 7000460     Active     Active  Active     Active  Active     Active
# 7000654     Active     Active  Active     Active  Active     Active
# ...            ...        ...     ...        ...     ...        ...
# 7039874          -          -       -          -       -          -
# 7039876          -          -       -          -       -          -
# 7039968          -          -       -          -       -          -
# 7040026          -          -       -          -       -          -
# 7040113          -          -       -          -       -          -
#
#               2021-10    2021-11    2021-12 2022-01  ...    2023-02   2023-03  \
# Unnamed: 0                                           ...
# ...

# %%
dealer_status[(dealer_status['2023-06']=='Active_3N')|(dealer_status['2023-07']=='Active_3N')&(dealer_status['month_new_dealer']>=12)]
# Out:
#            2021-04    2021-05 2021-06    2021-07 2021-08    2021-09  \
# Unnamed: 0
# 7000027     Active     Active  Active     Active  Active     Active
# 7000059     Active     Active  Active     Active  Active     Active
# 7000104          -     Active  Active     Active  Active     Active
# 7000218     Active     Active  Active  Active_1N  Active     Active
# 7000318     Active  Active_1N  Active  Active_1N  Active  Active_1N
# ...            ...        ...     ...        ...     ...        ...
# 7039592          -          -       -          -       -          -
# 7039593          -          -       -          -       -          -
# 7039597          -          -       -          -       -          -
# 7039715          -          -       -          -       -          -
# 7039790          -          -       -          -       -          -
#
#               2021-10    2021-11    2021-12 2022-01  ...   2023-02   2023-03  \
# Unnamed: 0                                           ...
# ...

# %%
dealer_status[(dealer_status['2023-05']=='Active_3N')|(dealer_status['2023-06']=='Active_3N')&(dealer_status['month_new_dealer']>=12)]
# Out:
#            2021-04 2021-05 2021-06 2021-07 2021-08 2021-09    2021-10 2021-11  \
# Unnamed: 0
# 7000027     Active  Active  Active  Active  Active  Active     Active  Active
# 7000085          -       -       -       -       -  Active  Active_1N  Active
# 7000104          -  Active  Active  Active  Active  Active     Active  Active
# 7000153     Active  Active  Active  Active  Active  Active     Active  Active
# 7000420     Active  Active  Active  Active  Active  Active     Active  Active
# ...            ...     ...     ...     ...     ...     ...        ...     ...
# 7039139          -       -       -       -       -       -          -       -
# 7039175          -       -       -       -       -       -          -       -
# 7039214          -       -       -       -       -       -          -       -
# 7039232          -       -       -       -       -       -          -       -
# 7039256          -       -       -       -       -       -          -       -
#
# ...

# %%
status_apr = status_apr[['2022-04','2022-05','2022-06','2022-07', '2022-08', '2022-09',
       '2022-10', '2022-11', '2022-12', '2023-01', '2023-02', '2023-03',
       'month_new_dealer']]
status_apr
# Out:
#               2022-04 2022-05    2022-06    2022-07 2022-08 2022-09 2022-10  \
# Unnamed: 0
# 7000085     Active_1N  Active     Active  Active_1N  Active  Active  Active
# 7000158        Active  Active  Active_1N     Active  Active  Active  Active
# 7000189     Active_1N  Active     Active     Active  Active  Active  Active
# 7000205             -       -          -          -       -       -       -
# 7000395        Active  Active     Active     Active  Active  Active  Active
# ...               ...     ...        ...        ...     ...     ...     ...
# 7039256             -       -          -          -       -       -       -
# 7039271             -       -          -          -       -       -       -
# 7039289             -       -          -          -       -       -       -
# 7039291             -       -          -          -       -       -       -
# 7039303             -       -          -          -       -       -       -
#
# ...

# %%
result_mar = result[result['creationTime']=='01-03-2023']
status_mar = dealer_status[dealer_status.index.isin(result_mar.index)]
status_mar['month_new_dealer'] = status_mar['month_new_dealer']-7
status_mar.drop(['2023-03','2023-04','2023-05','2023-06','2023-07', '2023-08', '2023-09',
       '2023-10'], axis = 1 , inplace = True)
# Out:
# /var/folders/m3/m633mc4s5tsggxm0f81370l80000gn/T/ipykernel_36210/3869496303.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   status_mar['month_new_dealer'] = status_mar['month_new_dealer']-7
# /var/folders/m3/m633mc4s5tsggxm0f81370l80000gn/T/ipykernel_36210/3869496303.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   status_mar.drop(['2023-03','2023-04','2023-05','2023-06','2023-07', '2023-08', '2023-09',

# %%
status_mar['2023-02'].value_counts()
# Out:
# Active_1N    374
# Active_2N    306
# Active        10
# Inactive       1
# Name: 2023-02, dtype: int64

# %%
status_apr['2023-03'].value_counts()
# Out:
# Active_1N    387
# Active_2N    322
# Active       142
# Name: 2023-03, dtype: int64

# %%
status_may['2023-04'].value_counts()
# Out:
# Active_1N    443
# Active_2N    377
# Active        18
# Name: 2023-04, dtype: int64

# %%
status_jun['2023-05'].value_counts()
# Out:
# Active_2N    446
# Active_1N    388
# Active         6
# Name: 2023-05, dtype: int64

# %%
status_jul['2023-06'].value_counts()
# Out:
# Active_1N    431
# Active_2N    406
# Active        15
# Name: 2023-06, dtype: int64

# %%
pivot = pd.read_excel('updated_pivot.xlsx')
pivot.index = pivot['Unnamed: 0']
pivot.drop('Unnamed: 0', axis= 1, inplace = True)

# %%
pivot['month_new_dealer'] = 31-pivot['month_new_dealer']

# %%
pivot_jul = pivot[pivot.index.isin(status_jul.index)]

# %%
pivot_jul['month_new_dealer'] = status_mar['month_new_dealer']-4
status_mar.drop(['2023-03','2023-04','2023-05','2023-06','2023-07', '2023-08', '2023-09',
       '2023-10'], axis = 1 , inplace = True)
# Out:
#             2021-04  2021-05  2021-06  2021-07  2021-08  2021-09  2021-10  \
# Unnamed: 0
# 7000059        30.0     85.0    30.00     15.0     60.0     32.5     77.5
# 7000218        10.0     12.0    24.00      0.0     24.0     12.0      0.0
# 7000318        30.0      0.0    29.00      0.0     30.0      0.0     25.0
# 7000460        33.0     12.0    15.00     10.0     15.0     10.0      0.0
# 7000654       270.5    205.9   234.95    219.0    359.4    276.0    325.7
# ...             ...      ...      ...      ...      ...      ...      ...
# 7040640         0.0      0.0     0.00      0.0      0.0      0.0      0.0
# 7040682         0.0      0.0     0.00      0.0      0.0      0.0      0.0
# 7040710         0.0      0.0     0.00      0.0      0.0      0.0      0.0
# 7040736         0.0      0.0     0.00      0.0      0.0      0.0      0.0
# 7040757         0.0      0.0     0.00      0.0      0.0      0.0      0.0
#
# ...

# %%
status_jul[status_jul['dealer_history']<=5].index.to_list()[:5]
# Out:
# [7010323, 7010342, 7010374, 7010479, 7010585]

# %%
status_jul_2 = status_jul[['2023-06']]
status_jun_2 = status_jun[['2023-05']]
status_may_2 = status_may[['2023-04']]

# %%
with pd.ExcelWriter('churn_status_2.xlsx') as excel_file:
    status_jul_2.to_excel(excel_file, sheet_name='1st_jul', index=True)
    status_jun_2.to_excel(excel_file, sheet_name='1st_jun', index=True)
    status_may_2.to_excel(excel_file, sheet_name='1st_may', index=True)

# %%
dealer_status
# Out:
#            2021-04 2021-05    2021-06 2021-07 2021-08    2021-09    2021-10  \
# Unnamed: 0
# 7000004     Active  Active     Active  Active  Active     Active     Active
# 7000010     Active  Active  Active_1N  Active  Active  Active_1N     Active
# 7000015     Active  Active     Active  Active  Active     Active     Active
# 7000019     Active  Active     Active  Active  Active     Active  Active_1N
# 7000022          -       -          -       -       -          -          -
# ...            ...     ...        ...     ...     ...        ...        ...
# 7042341          -       -          -       -       -          -          -
# 7042347          -       -          -       -       -          -          -
# 7042369          -       -          -       -       -          -          -
# 7042371          -       -          -       -       -          -          -
# 7042372          -       -          -       -       -          -          -
#
# ...

# %%
import numpy as np 
import psycopg2
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#Credentials for DB
host="database-dalmia.cms6cet2hwec.ap-south-1.rds.amazonaws.com"
database="dalmia_digital"
user="postgres"
password="dalmia123"
sql_query =  "SELECT sold_to_party_code,billing_date,bill_quantity FROM dalmia_sales.sales_data where billing_date > '2020-04-01' and sold_to_party_code between 7000000 and 7099999"


class DB_Data:
    
    def __init__(self, host, database, user, password, sql_query):
        self.host = host
        self.database = database
        self.user = user
        self.password = password
        self.sql_query = sql_query
        
#Database connection funtion        
    def db_data(self):
        conn = psycopg2.connect(
            host=self.host,
            database=self.database,
            user=self.user,
            password=self.password
        )
        sql_query = self.sql_query
        df = pd.read_sql_query(sql_query, conn)
        conn.close()
        return df

#Function to create date columns 
    def create_date_columns(self):
        df = self.db_data()
        new_df = pd.DataFrame()
        for df_item in [df]:
            df_item['date'] = pd.to_datetime(df_item['billing_date'])
            df_item['Month_Year'] = pd.to_datetime(df_item['date']).dt.strftime('%Y-%m')
            df_item['Year'] = pd.to_datetime(df_item['date']).dt.year
            df_item['Quarter'] = df_item['date'].dt.to_period('Q')
            new_df = pd.concat([new_df, df_item], axis=0)
        return new_df

#Pivot data creation for 
    def pivot_data(self):
        df = self.create_date_columns()
        df_sales = df[['sold_to_party_code', 'Month_Year', 'bill_quantity']]
        df_group_month = df_sales.groupby(['sold_to_party_code', 'Month_Year']).agg({'bill_quantity': 'sum'}).reset_index()
        df_group_month.columns = ['Sold To Party Code', 'Month Year', 'Sum']
        pivot_table = pd.pivot_table(df_group_month, values='Sum', columns='Month Year', index='Sold To Party Code')
        pivot_table = pivot_table.fillna(0)
        return pivot_table
    
#New Dealers    
    def count_zeros_before_first_nonzero(self , row):
        count = 0
        for value in row:
            if value == 0:
                count += 1
            else:
                break 
        return count

#Result_matrix creation
    def count_trailing_zeros_before_end_index(self, df, end_index):
        counts = []
        for row in df.itertuples(index=False):
            count = 0
            for i in range(end_index - 1, -1, -1):
                if row[i] == 0:
                    count += 1
                else:
                    break
            counts.append(count)
        return counts

    def create_result_matrix(self, month_new):
        df = self.pivot_data()
        df['month_new_dealer'] = df.apply(self.count_zeros_before_first_nonzero,axis =1)
        df = df[df['month_new_dealer']<=month_new]
        result_matrix = pd.DataFrame(index=df.index)
        for i in range(len(df.columns)):
            string = str(i)
            result_matrix[string] = self.count_trailing_zeros_before_end_index(df, i)
        result_matrix.drop('0', axis=1, inplace=True)
        return df , result_matrix
    
    def inactive(self , value):
        if value == 0: 
            return 'Active'
        elif value == 1: 
            return 'Active_1N'
        elif value == 2: 
            return 'Active_2N'
        elif value == 3: 
            return 'Active_3N'
        elif value>3 and value <=12:
            return 'Inactive'
        else: 
            return 'Churn'
        
#Activity Matrix      
    def state_matrix(self , month_new):
        df, result_matrix = self.create_result_matrix(month_new)
        for i in result_matrix.columns:
            result_matrix[i] = result_matrix[i].apply(self.inactive)
        result_matrix['month_new_dealer'] = df['month_new_dealer']
        for i in result_matrix.index:
            value = df.loc[i,'month_new_dealer'] 
            result_matrix.loc[i, :value] = '-'
        result_matrix.columns = df.columns
        df.drop('month_new_dealer', axis = 1 , inplace = True)
        result_matrix.drop('month_new_dealer', axis = 1 , inplace = True)
        return df, result_matrix

# %%
instance = DB_Data( host, database, user, password, sql_query)
df = instance.create_date_columns()

# %%
df = df[['sold_to_party_code', 'Month_Year', 'bill_quantity']]
df
# Out:
#          sold_to_party_code Month_Year  bill_quantity
# 0                   7016172    2021-09           19.0
# 1                   7025097    2021-09           25.0
# 2                   7023796    2021-09            4.5
# 3                   7023796    2021-09            0.5
# 4                   7025095    2021-09           20.0
# ...                     ...        ...            ...
# 4725658             7019648    2021-09           19.0
# 4725659             7031335    2021-09           19.0
# 4725660             7023265    2021-09            5.0
# 4725661             7021437    2021-09           10.0
# 4725662             7016635    2021-09            4.0
#
# [4725663 rows x 3 columns]

# %%
df[df['sold_to_party_code'].isin([7010323, 7010342, 7010374, 7010479, 7010585])]['Month_Year'].value_counts()
# Out:
# 2023-05    10
# 2023-08     5
# 2023-04     2
# 2023-07     2
# Name: Month_Year, dtype: int64

# %%
[7010323, 7010342, 7010374, 7010479, 7010585]

# %%
status_jul[status_jul.index.isin([7010323, 7010342, 7010374, 7010479, 7010585])]
# Out:
#            2022-07 2022-08 2022-09 2022-10 2022-11 2022-12 2023-01 2023-02  \
# Unnamed: 0
# 7010323          -       -       -       -       -       -       -       -
# 7010342          -       -       -       -       -       -       -       -
# 7010374          -       -       -       -       -       -       -       -
# 7010479          -       -       -       -       -       -       -       -
# 7010585          -       -       -       -       -       -       -       -
#
#            2023-03 2023-04 2023-05    2023-06  dealer_history
# Unnamed: 0
# 7010323          -       -  Active  Active_1N               2
# 7010342          -  Active  Active  Active_1N               3
# 7010374          -       -  Active  Active_1N               2
# 7010479          -  Active  Active  Active_1N               3
# 7010585          -       -  Active  Active_1N               2

# %%
import os
directory = 'data/Sales Data/'
def read_multiple_tables(directory):
    df_a = pd.DataFrame()
    for folder in os.listdir(directory):
        if folder not in ['.DS_Store', '.ipynb_checkpoints']:
            for file in os.listdir(os.path.join(directory , folder)):
                if file != '.ipynb_checkpoints':
                    files_dir = os.path.join(directory , folder , file)
                    df_1 = pd.read_excel(files_dir, engine='pyxlsb')
                df_a = pd.concat([df_a , df_1] , axis = 0)
    return df_a

# %%
df_a = read_multiple_tables(directory)

# %%
dealer_status[(dealer_status['2023-01'].isin(['Inactive',
                                            'Churn']))&(dealer_status['2023-10'].isin(['Active', 
                                                                                       'Active_1N','Active_2N']))].to_excel('dealer_status_history.xlsx')

# %%
df_a.head()
# Out:
#    Month  Billing Date Sales Region Sales Zone Sales Type Manufacturing Plant  \
# 0  44228         44229        South        Goa      Trade                1300
# 1  44228         44229        South        Goa      Trade                1300
# 2  44228         44229        South        Goa      Trade                1300
# 3  44228         44230        South        Goa      Trade                1300
# 4  44228         44231        South        Goa      Trade                1300
#
#   Manufacturing Plant Name Plant            Plant Name  Sold To Party Code  \
# 0     DCBL FACTORY-BELGAUM  1300  DCBL FACTORY-BELGAUM             7015228
# 1     DCBL FACTORY-BELGAUM  1300  DCBL FACTORY-BELGAUM             7015228
# 2     DCBL FACTORY-BELGAUM  1300  DCBL FACTORY-BELGAUM             7031240
# 3     DCBL FACTORY-BELGAUM  1300  DCBL FACTORY-BELGAUM             7031240
# 4     DCBL FACTORY-BELGAUM  1300  DCBL FACTORY-BELGAUM             7026324
#
# ...

# %%
import datetime
def timeseries_conversion(excel_serial_number):
    reference_date = datetime.datetime(1900, 1, 1)
    dt = reference_date + datetime.timedelta(days=excel_serial_number - 2)
    return dt
df_a['Billing Date'] = df_a['Billing Date'].apply(timeseries_conversion)

# %%
def create_date_columns(df_list):#pass the dataframe in the list format 
    new_df = pd.DataFrame()
    for i in df_list:
        #i['date'] = pd.to_datetime(i['Billing Date'])
        i['Month_Year'] = pd.to_datetime(i['date']).dt.strftime('%Y-%m')
        #i['Year'] = pd.to_datetime(i['date']).dt.year
        #i['Quarter'] = i['date'].dt.to_period('Q')
        new_df = pd.concat([new_df,i], axis=0)
    return new_df
df_sales = create_date_columns([df_a])

# %%
df_sales = df_a[['Sold To Party Code' ,'Month_Year','Bill Quantity']]

# %%
df_sales = df_sales[df_sales['Sold To Party Code'].isin(range(7000000,7100000))]

# %%
df_sales['Month_Year'].value_counts()
# Out:
# 2021-03    189973
# 2020-12    166066
# 2021-02    165135
# 2021-01    153949
# 2020-10    142850
# 2020-09    137908
# 2020-11    136126
# 2020-06    132307
# 2020-07    120922
# 2020-08    120343
# 2020-05    113957
# 2020-04     28156
# Name: Month_Year, dtype: int64

# %%
df_sales[df_sales['Sold To Party Code'].isin([7010323, 7010342, 7010374, 7010479, 7010585])]
# Out:
# Empty DataFrame
# Columns: [Sold To Party Code, Month_Year, Bill Quantity]
# Index: []
